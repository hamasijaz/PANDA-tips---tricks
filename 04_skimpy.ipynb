# %% [markdown]
# ## How to do Skiming the data

# %%
import pandas as pd
import seaborn as sns 
from skimpy import skim
import re

# %%
df = pd.read_csv('./data/data.csv')

# %%
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  ...  POPULATION 1998 (RURAL)  \
# ...

# %%
df.columns
# Out:
# Index(['PROVINCE', 'DIVISION', 'DISTRICT', 'SUB DIVISION', 'AREA (sq.km)',
#        'ALL SEXES (RURAL)', 'MALE (RURAL)', 'FEMALE (RURAL)',
#        'TRANSGENDER (RURAL)', 'SEX RATIO (RURAL)',
#        'AVG HOUSEHOLD SIZE (RURAL)', 'POPULATION 1998 (RURAL)',
#        'ANNUAL GROWTH RATE (RURAL)', 'ALL SEXES (URBAN)', 'MALE (URBAN)',
#        'FEMALE (URBAN)', 'TRANSGENDER (URBAN)', 'SEX RATIO (URBAN)',
#        'AVG HOUSEHOLD SIZE (URBAN)', 'POPULATION 1998 (URBAN)',
#        'ANNUAL GROWTH RATE (URBAN)'],
#       dtype='object')

# %%
# how i clean columns name in the dataset by skimpy
skim(df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 528    │ │ int64       │ 10    │                                                          │
# │ │ Number of columns │ 21     │ │ float64     │ 7     │                                                          │
# │ └───────────────────┴────────┘ │ string      │ 4     │                                                          │
# ...

# %%
skim(df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 528    │ │ int64       │ 10    │                                                          │
# │ │ Number of columns │ 21     │ │ float64     │ 7     │                                                          │
# │ └───────────────────┴────────┘ │ string      │ 4     │                                                          │
# ...

# %%
from skimpy import generate_test_data, skim_get_data

# %%
summary = skim_get_data(df)
print(summary)
# Out:
# {'Data Summary': {'Number of rows': 528, 'Number of columns': 21}, 'Data Types': {'int64': 10, 'float64': 7, 'string': 4}, 'number': {'NA': {'AREA (sq.km)': 0, 'ALL SEXES (RURAL)': 0, 'MALE (RURAL)': 0, 'FEMALE (RURAL)': 0, 'TRANSGENDER (RURAL)': 0, 'SEX RATIO (RURAL)': 0, 'AVG HOUSEHOLD SIZE (RURAL)': 0, 'POPULATION 1998 (RURAL)': 0, 'ANNUAL GROWTH RATE (RURAL)': 0, 'ALL SEXES (URBAN)': 0, 'MALE (URBAN)': 0, 'FEMALE (URBAN)': 0, 'TRANSGENDER (URBAN)': 0, 'SEX RATIO (URBAN)': 0, 'AVG HOUSEHOLD SIZE (URBAN)': 0, 'POPULATION 1998 (URBAN)': 0, 'ANNUAL GROWTH RATE (URBAN)': 0}, 'NA %': {'AREA (sq.km)': 0.0, 'ALL SEXES (RURAL)': 0.0, 'MALE (RURAL)': 0.0, 'FEMALE (RURAL)': 0.0, 'TRANSGENDER (RURAL)': 0.0, 'SEX RATIO (RURAL)': 0.0, 'AVG HOUSEHOLD SIZE (RURAL)': 0.0, 'POPULATION 1998 (RURAL)': 0.0, 'ANNUAL GROWTH RATE (RURAL)': 0.0, 'ALL SEXES (URBAN)': 0.0, 'MALE (URBAN)': 0.0, 'FEMALE (URBAN)': 0.0, 'TRANSGENDER (URBAN)': 0.0, 'SEX RATIO (URBAN)': 0.0, 'AVG HOUSEHOLD SIZE (URBAN)': 0.0, 'P
# ...

# %%
df.columns
# Out:
# Index(['PROVINCE', 'DIVISION', 'DISTRICT', 'SUB DIVISION', 'AREA (sq.km)',
#        'ALL SEXES (RURAL)', 'MALE (RURAL)', 'FEMALE (RURAL)',
#        'TRANSGENDER (RURAL)', 'SEX RATIO (RURAL)',
#        'AVG HOUSEHOLD SIZE (RURAL)', 'POPULATION 1998 (RURAL)',
#        'ANNUAL GROWTH RATE (RURAL)', 'ALL SEXES (URBAN)', 'MALE (URBAN)',
#        'FEMALE (URBAN)', 'TRANSGENDER (URBAN)', 'SEX RATIO (URBAN)',
#        'AVG HOUSEHOLD SIZE (URBAN)', 'POPULATION 1998 (URBAN)',
#        'ANNUAL GROWTH RATE (URBAN)'],
#       dtype='object')

# %%
from skimpy import clean_columns

# %%
columns = ['PROVINCE', 'DIVISION', 'DISTRICT', 'SUB DIVISION']
messy_df = pd.DataFrame(columns=columns, index=[0], data=[range(len(columns))])
print("Column names:")
print(list(messy_df.columns))
# Out:
# Column names:
# ['PROVINCE', 'DIVISION', 'DISTRICT', 'SUB DIVISION']

# %%
clean_df = clean_columns(messy_df)
print(list(clean_df.columns))
# Out:
# ['province', 'division', 'district', 'sub_division']
