# %% [markdown]
# ## Automatic EDA using  ``Ydata_Profiling``

# %%
import pandas as pd
import seaborn as sns 
import ydata_profiling as yd

# %%
# import data from seaborn
df = sns.load_dataset('titanic')

# %%
# ydata profiling report
profile = yd.ProfileReport(df)
profile.to_file('./data/titanic_report.html')
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 66.57it/s]

# %% [markdown]
# # Do it on our Pak population dataset

# %%
df_pk = pd.read_csv('./data/data.csv')
profile_pk = yd.ProfileReport(df_pk)

# %%
profile_pk.to_file('./data/pk_profile.html')
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00,  3.71it/s]
